# %% [markdown]
# <a href="https://colab.research.google.com/github/Archanatshinod/DSMLAB/blob/main/quartileplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
data =np.random.normal(30,1,500)
plt.boxplot(data)
plt.xlabel('value')
plt.ylabel('frequency')
plt.show()
